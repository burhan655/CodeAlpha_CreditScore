# %%
import pandas as pd 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **  First we import pandas libarary and import  warnings to ignore unnaccery errors

# %%
df=pd.read_csv("/kaggle/input/credit-score-classification/train.csv")
df1=pd.read_csv("/kaggle/input/credit-score-classification/test.csv")

# %%
df
# Out:
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  ...  \
# ...

# %%
car=df.select_dtypes("object")
num=df.select_dtypes(["int","float"])
car1=df1.select_dtypes("object")
num1=df1.select_dtypes(["int","float"])

# %%
car=car.fillna("0")
num=num.fillna(0)
car1=car1.fillna("0")
num1=num1.fillna(0)

# %%
df=pd.concat([car,num], axis=1)
df1=pd.concat([car1,num1], axis=1)

# %%
df1.isnull().sum()
# Out:
# ID                          0
# Customer_ID                 0
# Month                       0
# Name                        0
# Age                         0
# SSN                         0
# Occupation                  0
# Annual_Income               0
# Num_of_Loan                 0
# Type_of_Loan                0
# Num_of_Delayed_Payment      0
# Changed_Credit_Limit        0
# Credit_Mix                  0
# Outstanding_Debt            0
# Credit_History_Age          0
# Payment_of_Min_Amount       0
# Amount_invested_monthly     0
# Payment_Behaviour           0
# Monthly_Balance             0
# Monthly_Inhand_Salary       0
# Num_Bank_Accounts           0
# Num_Credit_Card             0
# Interest_Rate               0
# Delay_from_due_date         0
# Num_Credit_Inquiries        0
# Credit_Utilization_Ratio    0
# Total_EMI_per_month         0
# dtype: int64

# %%
car
# Out:
#             ID Customer_ID     Month           Name   Age          SSN  \
# 0       0x1602   CUS_0xd40   January  Aaron Maashoh    23  821-00-0265
# 1       0x1603   CUS_0xd40  February  Aaron Maashoh    23  821-00-0265
# 2       0x1604   CUS_0xd40     March  Aaron Maashoh  -500  821-00-0265
# 3       0x1605   CUS_0xd40     April  Aaron Maashoh    23  821-00-0265
# 4       0x1606   CUS_0xd40       May  Aaron Maashoh    23  821-00-0265
# ...        ...         ...       ...            ...   ...          ...
# 99995  0x25fe9  CUS_0x942c     April          Nicks    25  078-73-5990
# 99996  0x25fea  CUS_0x942c       May          Nicks    25  078-73-5990
# 99997  0x25feb  CUS_0x942c      June          Nicks    25  078-73-5990
# 99998  0x25fec  CUS_0x942c      July          Nicks    25  078-73-5990
# 99999  0x25fed  CUS_0x942c    August          Nicks    25  078-73-5990
#
#       Occupation Annual_Income Num_of_Loan  \
# 0      Scientist      19114.12           4
# ...

# %%
df1
# Out:
#             ID Customer_ID      Month             Name   Age          SSN  \
# 0       0x160a   CUS_0xd40  September    Aaron Maashoh    23  821-00-0265
# 1       0x160b   CUS_0xd40    October    Aaron Maashoh    24  821-00-0265
# 2       0x160c   CUS_0xd40   November    Aaron Maashoh    24  821-00-0265
# 3       0x160d   CUS_0xd40   December    Aaron Maashoh   24_  821-00-0265
# 4       0x1616  CUS_0x21b1  September  Rick Rothackerj    28  004-07-5839
# ...        ...         ...        ...              ...   ...          ...
# 49995  0x25fe5  CUS_0x8600   December   Sarah McBridec  4975  031-35-0942
# 49996  0x25fee  CUS_0x942c  September            Nicks    25  078-73-5990
# 49997  0x25fef  CUS_0x942c    October            Nicks    25  078-73-5990
# 49998  0x25ff0  CUS_0x942c   November            Nicks    25  078-73-5990
# 49999  0x25ff1  CUS_0x942c   December            Nicks    25  078-73-5990
#
#       Occupation Annual_Income Num_of_Loan  \
# ...

# %%
df=df[df.Credit_Mix!= "_"]
df=df[df.Occupation!= "_______"]
df=df[df.Delay_from_due_date!= -1]
df1=df1[df1.Credit_Mix!= "_"]
df1=df1[df1.Occupation!= "_______"]
df1=df1[df1.Delay_from_due_date!= -1]

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

df['Occupation']=label_encoder.fit_transform(df['Occupation'])


label_encoder = LabelEncoder()

df1['Occupation']=label_encoder.fit_transform(df1['Occupation'])

# %%
label_encoder = LabelEncoder()


df['Monthly_Balance' ] = label_encoder.fit_transform(df['Monthly_Balance'].astype(str))



label_encoder = LabelEncoder()


df1['Monthly_Balance' ] = label_encoder.fit_transform(df1['Monthly_Balance'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Payment_Behaviour' ] = label_encoder.fit_transform(df['Payment_Behaviour'].astype(str))



label_encoder = LabelEncoder()


df1['Payment_Behaviour' ] = label_encoder.fit_transform(df1['Payment_Behaviour'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Amount_invested_monthly' ] = label_encoder.fit_transform(df['Amount_invested_monthly'].astype(str))



label_encoder = LabelEncoder()


df1['Amount_invested_monthly' ] = label_encoder.fit_transform(df1['Amount_invested_monthly'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Payment_of_Min_Amount'] = label_encoder.fit_transform(df['Payment_of_Min_Amount'].astype(str))



label_encoder = LabelEncoder()


df1['Payment_of_Min_Amount'] = label_encoder.fit_transform(df1['Payment_of_Min_Amount'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Credit_History_Age'] = label_encoder.fit_transform(df['Credit_History_Age'].astype(str))



label_encoder = LabelEncoder()


df1['Credit_History_Age'] = label_encoder.fit_transform(df1['Credit_History_Age'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Outstanding_Debt'] = label_encoder.fit_transform(df['Outstanding_Debt'].astype(str))


label_encoder = LabelEncoder()


df1['Outstanding_Debt'] = label_encoder.fit_transform(df1['Outstanding_Debt'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Credit_Mix'] = label_encoder.fit_transform(df['Credit_Mix'].astype(str))


label_encoder = LabelEncoder()


df1['Credit_Mix'] = label_encoder.fit_transform(df1['Credit_Mix'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Changed_Credit_Limit'] = label_encoder.fit_transform(df['Changed_Credit_Limit'].astype(str))


label_encoder = LabelEncoder()


df1['Changed_Credit_Limit'] = label_encoder.fit_transform(df1['Changed_Credit_Limit'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Num_of_Delayed_Payment'] = label_encoder.fit_transform(df['Num_of_Delayed_Payment'].astype(str))


label_encoder = LabelEncoder()


df1['Num_of_Delayed_Payment'] = label_encoder.fit_transform(df1['Num_of_Delayed_Payment'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Type_of_Loan'] = label_encoder.fit_transform(df['Type_of_Loan'].astype(str))


label_encoder = LabelEncoder()


df1['Type_of_Loan'] = label_encoder.fit_transform(df1['Type_of_Loan'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Num_of_Loan'] = label_encoder.fit_transform(df['Num_of_Loan'].astype(str))


label_encoder = LabelEncoder()


df1['Num_of_Loan'] = label_encoder.fit_transform(df1['Num_of_Loan'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Annual_Income'] = label_encoder.fit_transform(df['Annual_Income'].astype(str))


label_encoder = LabelEncoder()


df1['Annual_Income'] = label_encoder.fit_transform(df1['Annual_Income'].astype(str))

# %%
label_encoder = LabelEncoder()


df['SSN'] = label_encoder.fit_transform(df['SSN'].astype(str))


label_encoder = LabelEncoder()


df1['SSN'] = label_encoder.fit_transform(df1['SSN'].astype(str))

# %%
label_encoder = LabelEncoder()


df['Age'] = label_encoder.fit_transform(df['Age'].astype(str))


label_encoder = LabelEncoder()


df1['Age'] = label_encoder.fit_transform(df1['Age'].astype(str))

# %%
df=df.drop(columns=['ID','Customer_ID','Month','Name'])

# %%
df.dtypes
# Out:
# Age                           int64
# SSN                           int64
# Occupation                    int64
# Annual_Income                 int64
# Num_of_Loan                   int64
# Type_of_Loan                  int64
# Num_of_Delayed_Payment        int64
# Changed_Credit_Limit          int64
# Credit_Mix                    int64
# Outstanding_Debt              int64
# Credit_History_Age            int64
# Payment_of_Min_Amount         int64
# Amount_invested_monthly       int64
# Payment_Behaviour             int64
# Monthly_Balance               int64
# Credit_Score                 object
# Monthly_Inhand_Salary       float64
# Num_Bank_Accounts             int64
# Num_Credit_Card               int64
# Interest_Rate                 int64
# Delay_from_due_date           int64
# Num_Credit_Inquiries        float64
# Credit_Utilization_Ratio    float64
# Total_EMI_per_month         float64
# dtype: object

# %%
df["Credit_Score"]=df["Credit_Score"].replace({
    "Good":0,
    "Standard":1,
    "Poor":2})

# %%
df
# Out:
#        Age    SSN  Occupation  Annual_Income  Num_of_Loan  Type_of_Loan  \
# 2        0  10205          12           5541          186           129
# 3      225  10205          12           5541          186           129
# 4      225  10205          12           5541          186           129
# 5      225  10205          12           5541          186           129
# 6      225  10205          12           5541          186           129
# ...    ...    ...         ...            ...          ...           ...
# 99991  331    406           1           6031          210          4914
# 99993  266   1009           9          10608          132           684
# 99997  266   1009           9          10607          132           684
# 99998  266   1009           9          10607          132           684
# 99999  266   1009           9          10608          132           684
#
#        Num_of_Delayed_Payment  Changed_Credit_Limit  Credit_Mix  \
# ...

# %%
df.corr()
# Out:
#                                Age       SSN  Occupation  Annual_Income  \
# Age                       1.000000 -0.010926   -0.007451      -0.029753
# SSN                      -0.010926  1.000000   -0.006608      -0.007171
# Occupation               -0.007451 -0.006608    1.000000       0.000778
# Annual_Income            -0.029753 -0.007171    0.000778       1.000000
# Num_of_Loan              -0.169588 -0.003715   -0.001509       0.078933
# Type_of_Loan             -0.040783  0.008950   -0.007154       0.035523
# Num_of_Delayed_Payment    0.041229 -0.015149   -0.000384      -0.013198
# Changed_Credit_Limit      0.032509 -0.002628    0.001101      -0.002945
# Credit_Mix                0.066867  0.004037    0.005896      -0.059438
# Outstanding_Debt          0.024034 -0.002360   -0.003410      -0.029847
# Credit_History_Age        0.021661 -0.007985   -0.013167      -0.001036
# Payment_of_Min_Amount    -0.147089  0.007417   -0.002153       0.059019
# ...

# %%
df.describe()
# Out:
#                 Age           SSN    Occupation  Annual_Income   Num_of_Loan  \
# count  74008.000000  74008.000000  74008.000000   74008.000000  74008.000000
# mean     414.111691   5910.289158      6.948195    8843.367095    148.031578
# std      203.712882   3785.589825      4.312219    5094.044312     95.653565
# min        0.000000      0.000000      0.000000       0.000000      0.000000
# 25%      248.000000   2589.000000      3.000000    4400.000000    131.000000
# 50%      394.000000   5895.000000      7.000000    8908.000000    160.000000
# 75%      575.000000   9187.250000     11.000000   13262.000000    210.000000
# max     1377.000000  12500.000000     14.000000   17568.000000    329.000000
#
#        Type_of_Loan  Num_of_Delayed_Payment  Changed_Credit_Limit  \
# count  74008.000000            74008.000000          74008.000000
# mean    2807.554467              181.545752           2480.991528
# std     1981.215446              182.832351           1225.324957
# ...

# %%
from tensorflow.keras.layers import Dense,Dropout
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
import numpy as np
# Out:
# 2025-10-27 15:29:47.756510: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1761578987.975679      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1761578988.035600      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
x=df.drop(columns=['Credit_Score'])
y=df['Credit_Score']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model=Sequential([Dense(32,activation="relu",input_dim=23),
                 Dense(3,activation="softmax")])
# Out:
# 2025-10-27 15:30:01.831166: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)

# %%
num_classes=len(np.unique(y))
num_classes
# Out:
# 3

# %%
from tensorflow.keras.utils import to_categorical
model.compile(optimizer="adam",loss="categorical_crossentropy",metrics=["accuracy"])
y_cat = to_categorical(y, num_classes=num_classes)
model.fit(x,y_cat,epochs=12)
# Out:
# Epoch 1/12
# 2313/2313 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.4262 - loss: 1050.5015
# Epoch 2/12
# 2313/2313 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4624 - loss: 66.2028
# Epoch 3/12
# 2313/2313 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4734 - loss: 52.4112
# Epoch 4/12
# 2313/2313 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4738 - loss: 44.3683
# Epoch 5/12
# 2313/2313 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4839 - loss: 39.8258
# Epoch 6/12
# 2313/2313 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4739 - loss: 41.3108
# Epoch 7/12
# 2313/2313 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4831 - loss: 39.3108
# Epoch 8/12
# 2313/2313 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4833 - loss: 37.6513
# Epoch 9/12
# 2313/2313 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4960 - loss: 34.6610
# Epoch 10/12
# 2313/2313 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4960 - loss: 33.8748
# Epoch 11/12
# ...
